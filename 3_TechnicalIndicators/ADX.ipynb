# %% [markdown]
# # ADX - Average Directional Index
#
# 1. ADX is a way of measuring the strength of a Trend.
# 1. Values range from 0 to 100 and quantifies the strength of the Trend as below:
#     1. 0-25: Absent or weak Trend
#         1. Trend can change direction any point of time and we may end up losing money.
#     1. 25-50: Strong Trend
#     1. 50-75: Very Strong Trend
#     1. 75-100: Extremly Strong Trend
# 1. ADX is non directional meaning that the ADX value makes no inference about the direction of the Trend but only about the strength of the Trend.
# 1. Calculation involves finding both positive and negative directional movements (by comparing successive highs and lows) and then calculating smoothed average of the difference of these.

# %%
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

import TECourse
from TechnicalIndicators import TechnicalIndicators

# %%
ticker = 'MSFT'
start = datetime.datetime.today() - datetime.timedelta(1200)
end = datetime.datetime.today()
ohlcv = pd.DataFrame()

# %%
ohlcv = yf.download(ticker, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = ohlcv.copy()
TechnicalIndicators.add_adx(df)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-03-04  226.740005  232.490005  224.259995  226.729996  226.729996
# 2021-03-05  229.520004  233.270004  226.460007  231.600006  231.600006
# 2021-03-08  231.369995  233.369995  227.130005  227.389999  227.389999
# 2021-03-09  232.880005  235.380005  231.669998  233.779999  233.779999
# 2021-03-10  237.000000  237.000000  232.039993  232.419998  232.419998
#
#               Volume        TR       ATR        ADX
# Date
# 2021-03-04  44584200  8.230011  5.279287  26.645022
# 2021-03-05  41842100  6.809998  5.582144  26.828966
# 2021-03-08  35245900  6.239990  5.798571  26.964505
# 2021-03-09  33034000  7.990005  6.128572  26.387933
# 2021-03-10  29733000  4.960007  6.244287  25.324454

# %%
df[['Adj Close', 'ADX']].plot(subplots=True, figsize=(10, 6));

# %%
df = ohlcv.copy()
df['ADX'] = TECourse.ADX(df, 14)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-03-04  226.740005  232.490005  224.259995  226.729996  226.729996
# 2021-03-05  229.520004  233.270004  226.460007  231.600006  231.600006
# 2021-03-08  231.369995  233.369995  227.130005  227.389999  227.389999
# 2021-03-09  232.880005  235.380005  231.669998  233.779999  233.779999
# 2021-03-10  237.000000  237.000000  232.039993  232.419998  232.419998
#
#               Volume        ADX
# Date
# 2021-03-04  44584200  26.645022
# 2021-03-05  41842100  26.828966
# 2021-03-08  35245900  26.964505
# 2021-03-09  33034000  26.387933
# 2021-03-10  29733000  25.324454

# %%
df[['Adj Close', 'ADX']].plot(subplots=True, figsize=(10, 6));
